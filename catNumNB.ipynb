# %%
import numpy as np
from IPython.display import IFrame
import pandas as pd 
import os
import shutil
import datetime
from pathlib import Path
import catNum

path = ""
dataset = pd.read_csv(path+"dataset.csv")

# %%
catNum.oneItemNB("cites_count.L5Y.median <= 89261.75",dataset,"Numerical 1Item Binary", 'n1Ib')
IFrame(src=path+'n1Ib.html', width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="n1Ib.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
catNum.twoItemNB("cites_count.speed.median <= 38460.00 AND sponsor_total.L5Y.mean <= 1886.67",dataset,"Numerical 2Item Binary", 'n2Ib')
IFrame(src=path+'n2Ib.html', width=1000, height=1000)
# Out:
# {'name': 'sponsor_total.L5Y.mean', 'operator': '<=', 'value': '1886.67'}
#         <iframe
#             width="1000"
#             height="1000"
#             src="n2Ib.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
catNum.threeItemNB("sponsor_total.L5Y.mean <= 1886.67 AND cites_count.speed.median <= 38429.50 AND conf_count.acc.std <= 387.46",dataset,"Numerical 3Item Binary", 'n3Ib')
IFrame(src=path+'n3Ib.html', width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="n3Ib.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
catNum.fourItemNB("access_open_count.L5Y.mean <= 2276.92 AND cites_count.speed.median <= 38460.00 AND cites_count.currentYear <= 4474.00 AND conf_count.L5Y.std <= 446.34",dataset,"Numerical 4Item Binary", 'n4Ib')
IFrame(src=path+'n4Ib.html', width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="n4Ib.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
dtIris = pd.read_csv(path+"IRIS.csv") 
dtIris = dtIris.rename(columns={"species": "class"})

# %%
catNum.oneItemNB("sepal_length >= 5.6",dtIris,"Numerical 1Item Multiclass","nm1")
IFrame(src=path+'nm1.html', width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="nm1.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
catNum.twoItemNB("sepal_length >= 5.6 AND sepal_width >= 2.3",dtIris,"Numerical 2Item Multiclass","nm2")
IFrame(src=path+'nm2.html', width=1000, height=1000)
# Out:
# {'name': 'sepal_width', 'operator': '>=', 'value': '2.3'}
#         <iframe
#             width="1000"
#             height="1000"
#             src="nm2.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
catNum.threeItemNB("sepal_length >= 5.6 AND sepal_width >= 2.3 AND petal_length >= 1.0",dtIris,"Numerical 3Item Multiclass","nm3")
IFrame(src=path+'nm3.html', width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="nm3.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
catNum.fourItemNB("sepal_length >= 5.6 AND sepal_width >= 2.3 AND petal_length >= 1.0 AND petal_width >= 0.4",dtIris,"Numerical 4Item Multiclass","nm4")
IFrame(src=path+'nm4.html', width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="nm4.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
dt3 = pd.read_csv(path+"online_shoppers_intention.csv") 
dt3 = dt3.rename(columns={"Revenue": "class"})
dt3 = dt3.iloc[:200,:]
dt3
# Out:
#      Administrative  Administrative_Duration  Informational  \
# 0               0.0                 0.000000            0.0
# 1               0.0                 0.000000            0.0
# 2               0.0                -1.000000            0.0
# 3               0.0                 0.000000            0.0
# 4               0.0                 0.000000            0.0
# 5               0.0                 0.000000            0.0
# 6               0.0                -1.000000            0.0
# 7               1.0                -1.000000            0.0
# 8               0.0                 0.000000            0.0
# 9               0.0                 0.000000            0.0
# 29                 0.000000            45.0              1582.750000
# ..                      ...             ...                      ...
# 170                0.000000            15.0               487.500000
# 171                0.000000            17.0               437.166667
# 172                0.000000             3.0                55.000000
# 173                0.000000             1.0                 0.000000
# 174                0.000000            24.0               446.927778
# 175                0.000000            10.0               320.500000
# 176                0.000000             7.0               666.000000
# 177                0.000000            21.0               405.709524
# 178                0.000000             1.0                 0.000000
# 179                0.000000             6.0               163.250000
# 180                0.000000            17.0               284.250000
# 181               -1.000000             1.0                -1.000000
# 182               -1.000000             1.0                -1.000000
# 183                0.000000             8.0               260.000000
# 184             1210.397619             5.0               279.857143
# 185                0.000000            20.0               927.450000
# 186                0.000000            50.0               836.800000
# 187              153.000000            96.0              3283.166739
# 188               48.500000            49.0              1868.819697
# 189               51.000000            68.0              3008.124108
# 190                0.000000             2.0                 0.000000
# 191                3.000000            24.0              3230.250000
# 192                0.000000             9.0               319.000000
# 193                0.000000             3.0                42.000000
# 194                0.000000            22.0               354.333333
# 195                0.000000            98.0              3556.612410
# 196              144.000000            67.0              2563.783333
# 197                0.000000            13.0              3014.018519
# 198                0.000000            17.0               840.233333
# 199              125.000000            55.0              1970.844805
#
#      BounceRates  ExitRates  PageValues  SpecialDay Month  OperatingSystems  \
# 0       0.200000   0.200000    0.000000         0.0   Feb                 1
# 1       0.000000   0.100000    0.000000         0.0   Feb                 2
# 2       0.200000   0.200000    0.000000         0.0   Feb                 4
# 3       0.050000   0.140000    0.000000         0.0   Feb                 3
# 4       0.020000   0.050000    0.000000         0.0   Feb                 3
# 5       0.015789   0.024561    0.000000         0.0   Feb                 2
# 6       0.200000   0.200000    0.000000         0.4   Feb                 2
# 7       0.200000   0.200000    0.000000         0.0   Feb                 1
# 8       0.000000   0.100000    0.000000         0.8   Feb                 2
# 9       0.000000   0.022222    0.000000         0.4   Feb                 2
# 10      0.000000   0.066667    0.000000         0.0   Feb                 1
# 11      0.018750   0.025833    0.000000         0.4   Feb                 1
# 12      0.000000   0.028571    0.000000         0.0   Feb                 1
# 13      0.000000   0.066667    0.000000         0.0   Feb                 2
# 14      0.000000   0.100000    0.000000         0.0   Feb                 3
# 15      0.008333   0.016313    0.000000         0.0   Feb                 1
# 16      0.200000   0.200000    0.000000         0.0   Feb                 1
# 17      0.000000   0.007692    0.000000         0.0   Feb                 1
# 18      0.000000   0.100000    0.000000         0.0   Feb                 2
# 19      0.000000   0.010000    0.000000         0.0   Feb                 2
# 20      0.000000   0.008333    0.000000         1.0   Feb                 2
# 21      0.200000   0.200000    0.000000         0.0   Feb                 3
# 22      0.000000   0.033333    0.000000         0.0   Feb                 3
# 23      0.000000   0.100000    0.000000         0.8   Feb                 2
# 24      0.200000   0.200000    0.000000         0.0   Feb                 2
# 25      0.000000   0.040000    0.000000         0.0   Feb                 1
# 26      0.002857   0.009524    0.000000         0.0   Feb                 2
# 27      0.050000   0.100000    0.000000         0.0   Feb                 1
# 28      0.000000   0.050000    0.000000         0.2   Feb                 2
# 29      0.043478   0.050821   54.179764         0.4   Feb                 3
# ..           ...        ...         ...         ...   ...               ...
# 170     0.000000   0.019167    0.000000         0.8   Feb                 1
# 171     0.011111   0.033333    0.000000         0.0   Feb                 2
# 172     0.066667   0.100000    0.000000         0.6   Feb                 1
# 173     0.200000   0.200000    0.000000         0.8   Feb                 1
# 174     0.000000   0.008602    0.000000         1.0   Feb                 2
# 175     0.000000   0.015385    0.000000         0.0   Feb                 1
# 176     0.000000   0.014286    0.000000         0.0   Feb                 1
# 177     0.010744   0.047003    0.000000         0.0   Feb                 1
# 178     0.200000   0.200000    0.000000         0.0   Feb                 3
# 179     0.033333   0.033333    0.000000         0.6   Feb                 1
# 180     0.000000   0.011765    0.000000         0.0   Feb                 3
# 181     0.200000   0.200000    0.000000         0.6   Feb                 4
# 182     0.200000   0.200000    0.000000         0.0   Feb                 2
# 183     0.008333   0.025000    0.000000         0.8   Feb                 3
# 184     0.003175   0.012764    0.000000         0.0   Mar                 2
# 185     0.011111   0.027249    8.000741         0.0   Mar                 1
# 186     0.000000   0.006340    0.000000         0.0   Mar                 2
# 187     0.001961   0.013509    0.000000         0.0   Mar                 3
# 188     0.000000   0.020709    1.706015         0.0   Mar                 2
# 189     0.007143   0.016728   46.530175         0.0   Mar                 2
# 190     0.200000   0.200000    0.000000         0.0   Mar                 1
# 191     0.036190   0.096000    0.000000         0.0   Mar                 2
# 192     0.000000   0.020000    0.000000         0.0   Mar                 1
# 193     0.000000   0.066667    0.000000         0.0   Mar                 2
# 194     0.009091   0.057662    0.000000         0.0   Mar                 1
# 195     0.002062   0.010173    0.000000         0.0   Mar                 1
# 196     0.000000   0.005797   19.342650         0.0   Mar                 2
# 197     0.013068   0.061406    0.000000         0.0   Mar                 2
# 198     0.000000   0.001667  109.176000         0.0   Mar                 2
# 199     0.000000   0.001724   96.255116         0.0   Mar                 2
#
#      Browser  Region  TrafficType        VisitorType  Weekend  class
# 0          1       1            1  Returning_Visitor    False  False
# 1          2       1            2  Returning_Visitor    False  False
# 2          1       9            3  Returning_Visitor    False  False
# 3          2       2            4  Returning_Visitor    False  False
# 4          3       1            4  Returning_Visitor     True  False
# 5          2       1            3  Returning_Visitor    False  False
# 6          4       3            3  Returning_Visitor    False  False
# 7          2       1            5  Returning_Visitor     True  False
# 8          2       2            3  Returning_Visitor    False  False
# 9          4       1            2  Returning_Visitor    False  False
# 10         1       3            3  Returning_Visitor    False  False
# 11         1       4            3  Returning_Visitor    False  False
# 12         1       1            3  Returning_Visitor    False  False
# 13         5       1            3  Returning_Visitor    False  False
# 14         2       3            3  Returning_Visitor    False  False
# 15         1       9            3  Returning_Visitor    False  False
# 16         1       4            3  Returning_Visitor    False  False
# 17         1       1            4  Returning_Visitor     True  False
# 18         2       1            3  Returning_Visitor    False  False
# 19         4       4            4  Returning_Visitor    False  False
# 20         2       5            1  Returning_Visitor     True  False
# 21         3       1            3  Returning_Visitor    False  False
# 22         2       1            5  Returning_Visitor    False  False
# 23         4       1            3  Returning_Visitor    False  False
# 24         2       4            1  Returning_Visitor     True  False
# 25         1       9            3  Returning_Visitor    False  False
# 26         2       1            3  Returning_Visitor    False  False
# 27         1       1            3  Returning_Visitor    False  False
# 28         6       1            3  Returning_Visitor    False  False
# 29         2       1            1  Returning_Visitor    False  False
# ..       ...     ...          ...                ...      ...    ...
# 170        1       2            4  Returning_Visitor     True  False
# 171        4       1            3  Returning_Visitor    False  False
# 172        1       1            3  Returning_Visitor    False  False
# 173        1       1            2  Returning_Visitor     True  False
# 174        2       8            1  Returning_Visitor     True  False
# 175        1       2            3  Returning_Visitor    False  False
# 176        1       6            2  Returning_Visitor    False  False
# 177        1       1            4  Returning_Visitor    False  False
# 178        2       3            3  Returning_Visitor    False  False
# 179        1       6            2  Returning_Visitor    False  False
# 180        2       6            2  Returning_Visitor     True  False
# 181        2       1            3  Returning_Visitor    False  False
# 182        4       1            1  Returning_Visitor    False  False
# 183        2       1            3  Returning_Visitor     True  False
# 184        2       1            8  Returning_Visitor    False  False
# 185        1       3            1  Returning_Visitor    False  False
# 186        2       3            2  Returning_Visitor    False  False
# 187        2       6            2  Returning_Visitor     True  False
# 188        2       7            2  Returning_Visitor    False   True
# 189        2       1            1  Returning_Visitor    False  False
# 190        1       1            3  Returning_Visitor    False  False
# 191        2       1            2  Returning_Visitor    False  False
# 192        1       1            1  Returning_Visitor    False  False
# 193        2       3            1  Returning_Visitor    False  False
# 194        1       7            2  Returning_Visitor     True  False
# 195        1       1            3  Returning_Visitor    False  False
# 196        2       4            2        New_Visitor    False   True
# 197        2       1            2  Returning_Visitor    False  False
# 198        2       9            2        New_Visitor    False   True
# 199        4       1            2        New_Visitor     True   True
#
# [200 rows x 18 columns]

# %%
catNum.oneItemCatNum("BounceRates > 0.0 AND Month == Feb",dt3,"NumericalCategorical 1Item Binary","nc1")
IFrame(src=path+'nc1.html', width=1000, height=1000)
# Out:
# ['BounceRates > 0.0', 'Month == Feb']
#         <iframe
#             width="1000"
#             height="1000"
#             src="nc1.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
catNum.twoItemCatNum("BounceRates > 0.0 AND Administrative_Duration < 50 AND Month == Feb",dt3,"NumericalCategorical 2Item Binary","nc2")
IFrame(src=path+'nc2.html', width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="nc2.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
catNum.threeItemCatNum("BounceRates > 0.0 AND Administrative_Duration < 50 AND ProductRelated_Duration < 100 AND Month == Feb",dt3,"NumericalCategorical 3Item Binary","nc3")
IFrame(src=path+'nc3.html', width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="nc3.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
catNum.fourItemCatNum("BounceRates > 0.0 AND Administrative_Duration < 50 AND ProductRelated_Duration < 100 AND BounceRates > 0 AND Month == Feb",dt3,"NumericalCategorical 4Item Binary","nc4")
IFrame(src=path+'nc4.html', width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="nc4.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
